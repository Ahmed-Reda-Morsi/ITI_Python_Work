# %% [markdown]
# # Bank system
# ## Frozen set for each user to save his accounts numbers

# %%
# define a dictionary for Customers accounts  
CUSTOMERS = {}

#Add a customer to the bank with the given name and account numbers.
def add_customer(name, account_numbers):
    CUSTOMERS[name] = {'accounts': frozenset(account_numbers), 'balances': {}}

# Remove a customer from the bank with the given name.
def remove_customer(name):
    del CUSTOMERS[name]

# Get the account numbers for a customer with the given name.
def get_customer_accounts(name):
    return CUSTOMERS[name]['accounts']

#Deposit funds into the specified account for the customer with the given name.
def deposit(name, account_number, amount):
    if account_number not in CUSTOMERS[name]['balances']:
        CUSTOMERS[name]['balances'][account_number] = amount
    else:
        CUSTOMERS[name]['balances'][account_number] += amount


#Withdraw funds from the specified account for the customer with the given name.
def withdraw(name, account_number, amount):
    balance = CUSTOMERS[name]['balances'][account_number]
    if balance < amount:
        print('Insufficient funds')
        return
    CUSTOMERS[name]['balances'][account_number] = balance - amount

def BankSystem():
    while True:
        print("___________| Bank System for admins |__________")
        print(' please seclect the operation.')
        print(' 1-> Add Customer.')
        print(' 2-> remove admin.')
        print(' 0-> exit.')







add_customer('Ahmed', [1001, 1002, 1003])
add_customer('Ali', [2001, 2002])
add_customer('Abd', [3001, 3002, 3003, 3004])

deposit('Ahmed',1001,45600)
deposit('Ahmed',1001,10600)
withdraw ('Ahmed',1001,100000)

print(CUSTOMERS['Ahmed']['balances'])  
print(CUSTOMERS['Ali']['balances'])  
print(CUSTOMERS['Abd']['balances'])
# Out:
# Insufficient funds
# {1001: 56200}
# {}
# {}

# %%
# define a dictionary for Customers accounts  
CUSTOMERS = {}

#Add a customer to the bank with the given name and account numbers.
def add_customer(name, account_numbers):
    CUSTOMERS[name] = {'accounts': frozenset(account_numbers), 'balances': {}}

# Remove a customer from the bank with the given name.
def remove_customer(name):
    del CUSTOMERS[name]

# Get the account numbers for a customer with the given name.
def get_customer_accounts(name):
    return CUSTOMERS[name]['accounts']

#Deposit funds into the specified account for the customer with the given name.
def deposit(name, account_number, amount):
    if account_number not in CUSTOMERS[name]['balances']:
        CUSTOMERS[name]['balances'][account_number] = amount
    else:
        CUSTOMERS[name]['balances'][account_number] += amount


#Withdraw funds from the specified account for the customer with the given name.
def withdraw(name, account_number, amount):
    balance = CUSTOMERS[name]['balances'][account_number]
    if balance < amount:
        print('Insufficient funds')
        return
    CUSTOMERS[name]['balances'][account_number] = balance - amount

def BankSystem():
    while True:
        print("___________| Bank System for admins |__________")
        print(' please seclect the operation.')
        print(' 1-> Add Customer.')
        print(' 2-> remove admin.')
        print(' 0-> exit.')







add_customer('Ahmed', [1001, 1002, 1003])
add_customer('Ali', [2001, 2002])
add_customer('Abd', [3001, 3002, 3003, 3004])

deposit('Ahmed',1001,45600)
deposit('Ahmed',1001,10600)
withdraw ('Ahmed',1001,100000)

print(CUSTOMERS['Ahmed']['balances'])  
print(CUSTOMERS['Ali']['balances'])  
print(CUSTOMERS['Abd']['balances'])
# Out:
# Insufficient funds
# {1001: 56200}
# {}
# {}

# %%
# define a dictionary for Customers accounts  
CUSTOMERS = {}

#Add a customer to the bank with the given name and account numbers.
def add_customer(name, account_numbers):
    CUSTOMERS[name] = {'accounts': frozenset(account_numbers), 'balances': {}}

# Remove a customer from the bank with the given name.
def remove_customer(name):
    del CUSTOMERS[name]

# Get the account numbers for a customer with the given name.
def get_customer_accounts(name):
    return CUSTOMERS[name]['accounts']

#Deposit funds into the specified account for the customer with the given name.
def deposit(name, account_number, amount):
    if account_number not in CUSTOMERS[name]['balances']:
        CUSTOMERS[name]['balances'][account_number] = amount
    else:
        CUSTOMERS[name]['balances'][account_number] += amount


#Withdraw funds from the specified account for the customer with the given name.
def withdraw(name, account_number, amount):
    balance = CUSTOMERS[name]['balances'][account_number]
    if balance < amount:
        print('Insufficient funds')
        return
    CUSTOMERS[name]['balances'][account_number] = balance - amount

def BankSystem():
    while True:
        print("___________| Bank System for admins |__________")
        print(' please seclect the operation.')
        print(' 1-> Add Customer.')
        print(' 2-> remove admin.')
        print(' 0-> exit.')







add_customer('Ahmed', [1001, 1002, 1003])
add_customer('Ali', [2001, 2002])
add_customer('Abd', [3001, 3002, 3003, 3004])

deposit('Ahmed',1001,45600)
deposit('Ahmed',1001,10600)
withdraw ('Ahmed',1001,100000)

print(CUSTOMERS['Ahmed']['balances'])  
print(CUSTOMERS['Ali']['balances'])  
print(CUSTOMERS['Abd']['balances'])
# Out:
# Insufficient funds
# {1001: 56200}
# {}
# {}

# %%
# define a dictionary for Customers accounts  
CUSTOMERS = {}

#Add a customer to the bank with the given name and account numbers.
def add_customer(name, account_numbers):
    CUSTOMERS[name] = {'accounts': frozenset(account_numbers), 'balances': {}}

# Remove a customer from the bank with the given name.
def remove_customer(name):
    del CUSTOMERS[name]

# Get the account numbers for a customer with the given name.
def get_customer_accounts(name):
    return CUSTOMERS[name]['accounts']

#Deposit funds into the specified account for the customer with the given name.
def deposit(name, account_number, amount):
    if account_number not in CUSTOMERS[name]['balances']:
        CUSTOMERS[name]['balances'][account_number] = amount
    else:
        CUSTOMERS[name]['balances'][account_number] += amount


#Withdraw funds from the specified account for the customer with the given name.
def withdraw(name, account_number, amount):
    balance = CUSTOMERS[name]['balances'][account_number]
    if balance < amount:
        print('Insufficient funds')
        return
    CUSTOMERS[name]['balances'][account_number] = balance - amount

def BankSystem():
    while True:
        print("___________| Bank System for admins |__________")
        print(' please seclect the operation.')
        print(' 1-> Add Customer.')
        print(' 2-> remove admin.')
        print(' 3-> get customer accounts.')
        print(' 4-> deposit.')
        print(' 5 -> withdraw.')

        operation=int(input("your operation number : "))
        print('_________________________________________________')

        name=input("Customer name :")
        if  operation==1:
            customer_accounts=input("customer accounts numbers as 0000-0000 ..")
            add_customer(name,customer_accounts)
        elif  operation==2:
            remove_customer(name)
        elif  operation==3:
            get_customer_accounts(name)
        elif  operation==4:
            customer_account=int(input(" customer account: "))
            amount=int(input(" customer amount to deposit : "))
            deposit(name,customer_account,amount)
        elif  operation==5:
            customer_account=int(input(" customer account: "))
            amount=int(input(" customer amount to withdraw : "))
            withdraw(name,customer_account,amount)
        else:
            print("wrong operation number!!")



BankSystem()




""" add_customer('Ahmed', [1001, 1002, 1003])
add_customer('Ali', [2001, 2002])
add_customer('Abd', [3001, 3002, 3003, 3004])

deposit('Ahmed',1001,45600)
deposit('Ahmed',1001,10600)
withdraw ('Ahmed',1001,100000)

print(CUSTOMERS['Ahmed']['balances'])  
print(CUSTOMERS['Ali']['balances'])  
print(CUSTOMERS['Abd']['balances'])  """
# Out:
# ___________| Bank System for admins |__________
#  please seclect the operation.
#  1-> Add Customer.
#  2-> remove admin.
#  3-> get customer accounts.
#  4-> deposit.
#  5 -> withdraw.
# _________________________________________________
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 66
#      61         else:
#      62             print("wrong operation number!!")
# ---> 66 BankSystem()
#      71 """ add_customer('Ahmed', [1001, 1002, 1003])
#      72 add_customer('Ali', [2001, 2002])
#      73 add_customer('Abd', [3001, 3002, 3003, 3004])
#    (...)
#      80 print(CUSTOMERS['Ali']['balances'])
#      81 print(CUSTOMERS['Abd']['balances'])  """
#
# Cell In[32], line 47, in BankSystem()
#      45 name=input("Customer name :")
#      46 if  operation==1:
# ---> 47     customer_accounts=input("customer accounts numbers as 0000-0000 ..").split("-",int)
# ...
